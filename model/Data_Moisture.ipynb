# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import logging
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# from efficientnet.keras import preprocess_input
from keras.models import load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Layer, ReLU, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Add, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,ConfusionMatrixDisplay
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Input, AveragePooling2D, ReLU, AlphaDropout, Conv2D, GlobalAveragePooling2D, Dense, Add, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import InceptionV3, VGG16, MobileNetV2, ResNet50V2
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,ConfusionMatrixDisplay
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from google.colab import files

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from keras.utils import load_img, img_to_array

tf.get_logger().setLevel(logging.ERROR)

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
img_rows, img_cols = 224, 224
channel_depth = 3
input_shape = (img_rows,img_cols,channel_depth)
model_input = Input(shape=input_shape)

# %% [markdown]
# **DenseNet121**

# %%
def my_model1(model_input):
    densenet = DenseNet121(weights='imagenet', include_top=False, input_tensor=model_input)
    for layer in densenet.layers:layer.trainable = False
    # our layers - you can add more if you want
    y = GlobalAveragePooling2D()(densenet.output)
    y = Dense(512, activation='relu', use_bias=True)(y)
    y = Dropout(0.5)(y)
    prediction = Dense(5,activation='softmax')(y)
    model = Model(inputs=densenet.input, outputs=prediction)
    # tell the model what cost and optimization method to use
    return model

# %%
model1 = my_model1(model_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step

# %% [markdown]
# **InceptionV3**

# %%
def my_model2(model_input):
    InceptionV3_builder = InceptionV3(
        weights='imagenet',
        include_top=False,
        input_tensor = model_input
    )

#FINE-TUNING
    for layer in InceptionV3_builder.layers:
        layer.trainable = False
    for BatchNormalization in InceptionV3_builder.layers:
        BatchNormalization.trainable = True
    x = InceptionV3_builder.layers[-1].output
    x = GlobalAveragePooling2D(name='GAP-inceptionv3')(x)
    x = Dropout(0.5, name='Droput-inceptionv3')(x)
    predictions = Dense(5, activation='softmax', name='Softmax-inceptionv3')(x)
    model = Model(inputs=InceptionV3_builder.input, outputs=predictions, name='inceptionv3')
    return model

# %%
model2 = my_model2(model_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %% [markdown]
# **VGG16**

# %%
def my_model3(model_input):
    densenet = VGG16(weights='imagenet', include_top=False, input_tensor=model_input)
    for layer in densenet.layers:layer.trainable = False
    # our layers - you can add more if you want
    y = GlobalAveragePooling2D()(densenet.output)
    y = Dense(512, activation='relu', use_bias=True)(y)
    y = Dropout(0.5)(y)
    prediction = Dense(5,activation='softmax')(y)
    model = Model(inputs=densenet.input, outputs=prediction)
    # tell the model what cost and optimization method to use
    return model

# %%
model3 = my_model3(model_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %% [markdown]
# **Fusion Model**

# %%
models = [model1, model2, model3]

# %%
[m.layers[0] for m in models]
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f4bbc05d060>,
#  <keras.engine.input_layer.InputLayer at 0x7f4bbc05d060>,
#  <keras.engine.input_layer.InputLayer at 0x7f4bbc05d060>]

# %%
outputs = [m.output for m in models]
y = tf.keras.layers.Average()(outputs)
TDCNN = Model(model_input, y, name='TDCNN')

# %% [markdown]
# **Pre-processing the images**

# %%
train_path="/content/drive/MyDrive/Bangkit Capstone/data_moistures/train"
validation_path= "/content/drive/MyDrive/Bangkit Capstone/data_moistures/val"
test_path="/content/drive/MyDrive/Bangkit Capstone/data_moistures/test"

# %%
IMG_SIZE = (224,224)

def ImgDataGen(file_path, f=False):
    file_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

    data_set = file_datagen.flow_from_directory(file_path,
                                                target_size = IMG_SIZE,
                                                batch_size = 16,
                                                class_mode = 'categorical',
                                                shuffle = f)
    return data_set

# %%
training_set, val_set, test_set = ImgDataGen(train_path,f=True), ImgDataGen(validation_path), ImgDataGen(test_path)
# Out:
# Found 324 images belonging to 5 classes.
# Found 92 images belonging to 5 classes.
# Found 50 images belonging to 5 classes.

# %%
nb_train_samples = len(training_set.filenames)
nb_validation_samples = len(val_set.filenames)
nb_test_samples = len(test_set.filenames)
num_classes= len(training_set.class_indices)
labels = [i for i in training_set.class_indices]
print(labels)
labels = ['13 %','13.2 %', '14 %', '15 %', '> 15 %']
# Out:
# ['0_13', '1_13.2', '2_14', '3_15', '4_15 (higher)']

# %% [markdown]
# **Train the model**

# %%
#MODEL COMPILATION WITH HYPER-PARAMETERS, LOSS FUNCTIONS AND TRAINING!
import time

batch_size = 16

epochs = 25

start_time = time.time()

optimizer = Adam(learning_rate=0.0001)

TDCNN.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=2,
    verbose=1,
    mode='max',
    min_lr=0.000001
)

callbacks = [reduce_lr]

history = TDCNN.fit(
    training_set,
    epochs=epochs,
    steps_per_epoch=nb_train_samples // batch_size,
    validation_data=val_set,
    callbacks=callbacks,
    validation_steps=nb_validation_samples // batch_size,
    verbose=1
)

elapsed_time = time.time() - start_time
time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
# Out:
# Epoch 1/25
# 20/20 [==============================] - 352s 14s/step - loss: 1.4582 - accuracy: 0.3766 - val_loss: 1.4890 - val_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 2/25
# 20/20 [==============================] - 59s 3s/step - loss: 1.0600 - accuracy: 0.6364 - val_loss: 1.4484 - val_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 3/25
# 20/20 [==============================] - 55s 3s/step - loss: 0.8987 - accuracy: 0.7760 - val_loss: 1.2634 - val_accuracy: 0.4500 - lr: 1.0000e-04
# Epoch 4/25
# 20/20 [==============================] - 59s 3s/step - loss: 0.7475 - accuracy: 0.9123 - val_loss: 1.0808 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 5/25
# 20/20 [==============================] - 62s 3s/step - loss: 0.6759 - accuracy: 0.9286 - val_loss: 0.9840 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Epoch 6/25
# 20/20 [==============================] - 60s 3s/step - loss: 0.5902 - accuracy: 0.9610 - val_loss: 0.9280 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 7/25
# 20/20 [==============================] - 54s 3s/step - loss: 0.5782 - accuracy: 0.9643 - val_loss: 0.8568 - val_accuracy: 0.7250 - lr: 1.0000e-04
# Epoch 8/25
# 20/20 [==============================] - 56s 3s/step - loss: 0.5559 - accuracy: 0.9708 - val_loss: 0.7561 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 9/25
# 20/20 [==============================] - 61s 3s/step - loss: 0.5502 - accuracy: 0.9708 - val_loss: 0.6527 - val_accuracy: 0.9250 - lr: 1.0000e-04
# Epoch 10/25
# 20/20 [==============================] - 61s 3s/step - loss: 0.5182 - accuracy: 0.9675 - val_loss: 0.6457 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 11/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4946 - accuracy: 0.9688
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 20/20 [==============================] - 55s 3s/step - loss: 0.4946 - accuracy: 0.9688 - val_loss: 0.6141 - val_accuracy: 0.8625 - lr: 1.0000e-04
# Epoch 12/25
# 20/20 [==============================] - 60s 3s/step - loss: 0.4734 - accuracy: 0.9740 - val_loss: 0.5950 - val_accuracy: 0.9125 - lr: 5.0000e-05
# Epoch 13/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4685 - accuracy: 0.9805
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 20/20 [==============================] - 63s 3s/step - loss: 0.4685 - accuracy: 0.9805 - val_loss: 0.5899 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 14/25
# 20/20 [==============================] - 61s 3s/step - loss: 0.4538 - accuracy: 0.9935 - val_loss: 0.5900 - val_accuracy: 0.8875 - lr: 2.5000e-05
# Epoch 15/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4554 - accuracy: 0.9870
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 20/20 [==============================] - 62s 3s/step - loss: 0.4554 - accuracy: 0.9870 - val_loss: 0.5798 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 16/25
# 20/20 [==============================] - 60s 3s/step - loss: 0.4504 - accuracy: 0.9935 - val_loss: 0.5700 - val_accuracy: 0.9000 - lr: 1.2500e-05
# Epoch 17/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4521 - accuracy: 0.9870
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 20/20 [==============================] - 62s 3s/step - loss: 0.4521 - accuracy: 0.9870 - val_loss: 0.5635 - val_accuracy: 0.9000 - lr: 1.2500e-05
# Epoch 18/25
# 20/20 [==============================] - 61s 3s/step - loss: 0.4410 - accuracy: 0.9838 - val_loss: 0.5581 - val_accuracy: 0.9125 - lr: 6.2500e-06
# Epoch 19/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.9805
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 20/20 [==============================] - 54s 3s/step - loss: 0.4440 - accuracy: 0.9805 - val_loss: 0.5516 - val_accuracy: 0.9125 - lr: 6.2500e-06
# Epoch 20/25
# 20/20 [==============================] - 62s 3s/step - loss: 0.4511 - accuracy: 0.9773 - val_loss: 0.5488 - val_accuracy: 0.9125 - lr: 3.1250e-06
# Epoch 21/25
# 20/20 [==============================] - 53s 3s/step - loss: 0.4399 - accuracy: 0.9870 - val_loss: 0.5453 - val_accuracy: 0.9375 - lr: 3.1250e-06
# Epoch 22/25
# 20/20 [==============================] - 59s 3s/step - loss: 0.4368 - accuracy: 0.9935 - val_loss: 0.5441 - val_accuracy: 0.9375 - lr: 3.1250e-06
# Epoch 23/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4427 - accuracy: 0.9935
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 20/20 [==============================] - 62s 3s/step - loss: 0.4427 - accuracy: 0.9935 - val_loss: 0.5426 - val_accuracy: 0.9375 - lr: 3.1250e-06
# Epoch 24/25
# 20/20 [==============================] - 61s 3s/step - loss: 0.4433 - accuracy: 0.9740 - val_loss: 0.5418 - val_accuracy: 0.9375 - lr: 1.5625e-06
# Epoch 25/25
# 20/20 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.9805
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
# 20/20 [==============================] - 60s 3s/step - loss: 0.4402 - accuracy: 0.9805 - val_loss: 0.5414 - val_accuracy: 0.9375 - lr: 1.5625e-06
# '00:33:54'

# %% [markdown]
# **Report**

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()

plt.savefig('vgg-loss-rps-1.png')
plt.show()

# %%
# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()

plt.savefig('vgg-acc-rps-1.png')
plt.show()

# %%
TDCNN.evaluate(test_set,batch_size=32)
y_pred=TDCNN.predict(test_set)
y_pred=np.argmax(y_pred,axis=1)
accuracy_score(y_pred,test_set.classes)
print(classification_report(y_pred,test_set.classes))

import seaborn as sns

# confusion_matrix
index = labels
columns = labels
cm = confusion_matrix(y_pred, test_set.classes)
cm_df = pd.DataFrame(cm,columns,index)
fig = plt.figure(figsize=(10,8),dpi=100)
fig = sns.heatmap(cm_df,cmap='Blues',annot=True, fmt="d",linewidths=1, square=True)
# Out:
# 4/4 [==============================] - 55s 11s/step - loss: 0.4456 - accuracy: 0.9400
# 4/4 [==============================] - 58s 11s/step
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       1.00      1.00      1.00         8
#            2       1.00      0.86      0.92        14
#            3       0.90      0.90      0.90        10
#            4       1.00      1.00      1.00        10
#
#     accuracy                           0.94        50
#    macro avg       0.94      0.95      0.94        50
# weighted avg       0.95      0.94      0.94        50

# %%
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'TDCNN'+'.svg'

figure = fig.get_figure()
figure.savefig(image_name, format=image_format, dpi=1200)

# %% [markdown]
# **Export the model**

# %%
file_model = "weights/TDCNN_1.h5"
tf.keras.models.save_model(TDCNN,file_model)

# %%
files.download(file_model)

# %%
import tensorflow as tf

model = tf.keras.models.load_model('model.h5')
